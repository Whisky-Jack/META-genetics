# %%
import numpy as np
from tensorflow import keras

# Model / data parameters
num_classes = 10
input_shape = (28, 28, 1)

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# Scale images to the [0, 1] range
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255

# Make sure images have shape (28, 28, 1)
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)
print("x_train shape:", x_train.shape)
print(x_train.shape[0], "train samples")
print(x_test.shape[0], "test samples")

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

training_set = (x_train, y_train)
validation_set = (x_test, y_test)
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %%
from genetics import Ecosystem

genes = Ecosystem(training_set, validation_set)
# Out:
# WARNING:tensorflow:From /home/bingley/miniconda3/envs/metagen/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Wrapping the env in a DummyVecEnv.
# WARNING:tensorflow:From /home/bingley/miniconda3/envs/metagen/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:191: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /home/bingley/miniconda3/envs/metagen/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /home/bingley/miniconda3/envs/metagen/lib/python3.6/site-packages/stable_baselines/common/policies.py:116: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /home/bingley/miniconda3/envs/metagen/lib/python3.6/site-packages/stable_baselines/common/input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/bingley/miniconda3/envs/metagen/lib/python3.6/site-packages/stable_baselines/common/policies.py:561: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f9116de5630>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f9116de5630>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f9116de5630>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f9116de5630>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:From /home/bingley/miniconda3/envs/metagen/lib/python3.6/site-packages/stable_baselines/common/tf_layers.py:123: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f910451b358>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f910451b358>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f910451b358>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f910451b358>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:From /home/bingley/miniconda3/envs/metagen/lib/python3.6/site-packages/stable_baselines/a2c/a2c.py:158: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /home/bingley/miniconda3/envs/metagen/lib/python3.6/site-packages/tensorflow/python/ops/clip_ops.py:286: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/bingley/miniconda3/envs/metagen/lib/python3.6/site-packages/stable_baselines/a2c/a2c.py:182: The name tf.train.RMSPropOptimizer is deprecated. Please use tf.compat.v1.train.RMSPropOptimizer instead.
#
# WARNING:tensorflow:From /home/bingley/miniconda3/envs/metagen/lib/python3.6/site-packages/tensorflow/python/training/rmsprop.py:119: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/bingley/miniconda3/envs/metagen/lib/python3.6/site-packages/stable_baselines/a2c/a2c.py:194: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# Train on 54000 samples, validate on 6000 samples
# 54000/54000 [==============================] - 5s 101us/sample - loss: 2.1255 - acc: 0.1771 - val_loss: 1.9506 - val_acc: 0.2133
# OBSERVATIONS:  (33920,)
# Train on 54000 samples, validate on 6000 samples
# 54000/54000 [==============================] - 7s 128us/sample - loss: 1.7785 - acc: 0.3445 - val_loss: 1.3810 - val_acc: 0.5077
# Train on 54000 samples, validate on 6000 samples
# 54000/54000 [==============================] - 6s 102us/sample - loss: 17.8959 - acc: 0.0992 - val_loss: 3.8515 - val_acc: 0.1000
# OBSERVATIONS:  (33920,)
# Train on 54000 samples, validate on 6000 samples
# 54000/54000 [==============================] - 2s 43us/sample - loss: 1.6203 - acc: 0.3993 - val_loss: 1.0371 - val_acc: 0.6552
# OBSERVATIONS:  (33920,)
# Train on 54000 samples, validate on 6000 samples
# 54000/54000 [==============================] - 4s 73us/sample - loss: 1.3150 - acc: 0.5603 - val_loss: 0.7568 - val_acc: 0.7603
# Train on 54000 samples, validate on 6000 samples
# 54000/54000 [==============================] - 6s 113us/sample - loss: 25.2068 - acc: 0.1439 - val_loss: 3.8048 - val_acc: 0.1468
# OBSERVATIONS:  (33920,)
# Train on 54000 samples, validate on 6000 samples
# 54000/54000 [==============================] - 6s 106us/sample - loss: 1.5778 - acc: 0.4392 - val_loss: 0.9771 - val_acc: 0.6322
# OBSERVATIONS:  (33920,)
# Train on 54000 samples, validate on 6000 samples
# 54000/54000 [==============================] - 2s 40us/sample - loss: 1.3851 - acc: 0.4919 - val_loss: 0.7805 - val_acc: 0.7550
# Train on 54000 samples, validate on 6000 samples
# 54000/54000 [==============================] - 4s 70us/sample - loss: 8.0569 - acc: 0.1089 - val_loss: 2.7578 - val_acc: 0.1087
# OBSERVATIONS:  (33920,)
# Train on 54000 samples, validate on 6000 samples
# 54000/54000 [==============================] - 2s 32us/sample - loss: 1.3364 - acc: 0.5280 - val_loss: 0.7335 - val_acc: 0.7525
# OBSERVATIONS:  (33920,)
# Train on 54000 samples, validate on 6000 samples
# 54000/54000 [==============================] - 2s 35us/sample - loss: 1.7299 - acc: 0.3201 - val_loss: 1.3848 - val_acc: 0.4305
# Train on 54000 samples, validate on 6000 samples
# 54000/54000 [==============================] - 4s 66us/sample - loss: 16.8715 - acc: 0.1647 - val_loss: 3.8156 - val_acc: 0.1695
# OBSERVATIONS:  (33920,)
# Train on 54000 samples, validate on 6000 samples
# 54000/54000 [==============================] - 7s 122us/sample - loss: 1.3190 - acc: 0.5254 - val_loss: 0.7913 - val_acc: 0.7400
# OBSERVATIONS:  (33920,)
# Train on 54000 samples, validate on 6000 samples
# 54000/54000 [==============================] - 5s 93us/sample - loss: 1.5570 - acc: 0.4082 - val_loss: 0.9875 - val_acc: 0.6662
# Train on 54000 samples, validate on 6000 samples
# 54000/54000 [==============================] - 5s 89us/sample - loss: 4.4947 - acc: 0.1024 - val_loss: 2.5830 - val_acc: 0.1048
# OBSERVATIONS:  (33920,)
# Train on 54000 samples, validate on 6000 samples
# 54000/54000 [==============================] - 8s 150us/sample - loss: 1.6557 - acc: 0.3850 - val_loss: 1.1505 - val_acc: 0.6197
# OBSERVATIONS:  (33920,)
# ---------------------------------
# | explained_variance | nan      |
# | fps                | 0        |
# | nupdates           | 1        |
# | policy_entropy     | 2.41e+04 |
# | total_timesteps    | 5        |
# | value_loss         | 0.107    |
# ---------------------------------
# Train on 54000 samples, validate on 6000 samples
# 54000/54000 [==============================] - 6s 120us/sample - loss: 1.9699 - acc: 0.2569 - val_loss: 1.7221 - val_acc: 0.4043
# Train on 54000 samples, validate on 6000 samples
# 54000/54000 [==============================] - 6s 117us/sample - loss: 6.0793 - acc: 0.0969 - val_loss: 2.9939 - val_acc: 0.1037
# OBSERVATIONS:  (33920,)
# Train on 54000 samples, validate on 6000 samples
# 54000/54000 [==============================] - 6s 110us/sample - loss: 1.7048 - acc: 0.3937 - val_loss: 1.3218 - val_acc: 0.4917
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-eb83fae85adf> in <module>
#       1 from genetics import Ecosystem
#       2
# ----> 3 genes = Ecosystem(training_set, validation_set)
#
# ~/Projects/META-genetics/genetics.py in __init__(self, training_set, validation_set, num_epochs, max_iter, pop_size, num_generations, RL)
#      52             self.predictor_net = RLPredictorNet(self.predictor_env)
#      53
# ---> 54             self.predictor_net.train()
#      55         else:
#      56             self.predictor_net = SupervisedPredictorNet(training_set, validation_set)
#
# ~/Projects/META-genetics/predictor.py in train(self, total_timesteps)
#      11
#      12     def train(self, total_timesteps=2000):
# ---> 13         self.model.learn(total_timesteps)
#      14
#      15 class SupervisedPredictorNet():
#
# ~/miniconda3/envs/metagen/lib/python3.6/site-packages/stable_baselines/a2c/a2c.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps)
#     259                 callback.on_rollout_start()
#     260                 # true_reward is the reward without discount
# --> 261                 rollout = self.runner.run(callback)
#     262                 # unpack
#     263                 obs, states, rewards, masks, actions, values, ep_infos, true_reward = rollout
#
# ~/miniconda3/envs/metagen/lib/python3.6/site-packages/stable_baselines/common/runners.py in run(self, callback)
#      46         self.callback = callback
#      47         self.continue_training = True
# ---> 48         return self._run()
#      49
#      50     @abstractmethod
#
# ~/miniconda3/envs/metagen/lib/python3.6/site-packages/stable_baselines/a2c/a2c.py in _run(self)
#     358             if isinstance(self.env.action_space, gym.spaces.Box):
#     359                 clipped_actions = np.clip(actions, self.env.action_space.low, self.env.action_space.high)
# --> 360             obs, rewards, dones, infos = self.env.step(clipped_actions)
#     361
#     362             self.model.num_timesteps += self.n_envs
#
# ~/miniconda3/envs/metagen/lib/python3.6/site-packages/stable_baselines/common/vec_env/base_vec_env.py in step(self, actions)
#     148         """
#     149         self.step_async(actions)
# --> 150         return self.step_wait()
#     151
#     152     def get_images(self, *args, **kwargs) -> Sequence[np.ndarray]:
#
# ~/miniconda3/envs/metagen/lib/python3.6/site-packages/stable_baselines/common/vec_env/dummy_vec_env.py in step_wait(self)
#      44                 # save final observation where user can get it, then reset
#      45                 self.buf_infos[env_idx]['terminal_observation'] = obs
# ---> 46                 obs = self.envs[env_idx].reset()
#      47             self._save_obs(env_idx, obs)
#      48         return (self._obs_from_buf(), np.copy(self.buf_rews), np.copy(self.buf_dones),
#
# ~/Projects/META-genetics/GeneticEnvironment.py in reset(self)
#      42         self.default_individual.mutate_layout()
#      43
# ---> 44         return self.get_state()
#      45
#      46     def compute_reward(self, default_training_data, pred_training_data):
#
# ~/Projects/META-genetics/GeneticEnvironment.py in get_state(self)
#      66
#      67     def get_state(self):
# ---> 68         old_individual_weights = self.individual.get_weights()
#      69         new_individual_weights = self.default_individual.get_weights()
#      70         new_individual_weights[new_individual_weights > 0.0] = 1.0
#
# ~/Projects/META-genetics/classifier_net.py in get_weights(self)
#      53         for lay in self.model.layers:
#      54             #print(lay.name)
# ---> 55             layer_weights = lay.get_weights()
#      56             if len(layer_weights) > 0:
#      57                 if layer_weights[0].shape[0] > self.max_layer_size:
#
# ~/miniconda3/envs/metagen/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer.py in get_weights(self)
#    1128     """
#    1129     params = self.weights
# -> 1130     return backend.batch_get_value(params)
#    1131
#    1132   def get_updates_for(self, inputs):
#
# ~/miniconda3/envs/metagen/lib/python3.6/site-packages/tensorflow/python/keras/backend.py in batch_get_value(tensors)
#    3008     raise RuntimeError('Cannot get value inside Tensorflow graph function.')
#    3009   if tensors:
# -> 3010     return get_session(tensors).run(tensors)
#    3011   else:
#    3012     return []
#
# ~/miniconda3/envs/metagen/lib/python3.6/site-packages/tensorflow/python/keras/backend.py in get_session(op_input_list)
#     460   if not _MANUAL_VAR_INIT:
#     461     with session.graph.as_default():
# --> 462       _initialize_variables(session)
#     463   return session
#     464
#
# ~/miniconda3/envs/metagen/lib/python3.6/site-packages/tensorflow/python/keras/backend.py in _initialize_variables(session)
#     884       v._keras_initialized = True
#     885     if uninitialized_vars:
# --> 886       session.run(variables_module.variables_initializer(uninitialized_vars))
#     887
#     888
#
# ~/miniconda3/envs/metagen/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     948     try:
#     949       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 950                          run_metadata_ptr)
#     951       if run_metadata:
#     952         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/miniconda3/envs/metagen/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1171     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1172       results = self._do_run(handle, final_targets, final_fetches,
# -> 1173                              feed_dict_tensor, options, run_metadata)
#    1174     else:
#    1175       results = []
#
# ~/miniconda3/envs/metagen/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1348     if handle is None:
#    1349       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1350                            run_metadata)
#    1351     else:
#    1352       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/miniconda3/envs/metagen/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1354   def _do_call(self, fn, *args):
#    1355     try:
# -> 1356       return fn(*args)
#    1357     except errors.OpError as e:
#    1358       message = compat.as_text(e.message)
#
# ~/miniconda3/envs/metagen/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1339       self._extend_graph()
#    1340       return self._call_tf_sessionrun(
# -> 1341           options, feed_dict, fetch_list, target_list, run_metadata)
#    1342
#    1343     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/miniconda3/envs/metagen/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1427     return tf_session.TF_SessionRun_wrapper(
#    1428         self._session, options, feed_dict, fetch_list, target_list,
# -> 1429         run_metadata)
#    1430
#    1431   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
