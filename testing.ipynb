# %%
import numpy as np
from tensorflow import keras

# Model / data parameters
num_classes = 10
input_shape = (28, 28, 1)

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# Scale images to the [0, 1] range
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255

# Make sure images have shape (28, 28, 1)
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)
print("x_train shape:", x_train.shape)
print(x_train.shape[0], "train samples")
print(x_test.shape[0], "test samples")

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

training_set = (x_train, y_train)
validation_set = (x_test, y_test)
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %%
from genetics import Ecosystem

genes = Ecosystem(training_set, validation_set)
# Out:
# WARNING:tensorflow:From /home/bingley/miniconda3/envs/metagen/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Training base:
# Train on 54000 samples, validate on 6000 samples
# 54000/54000 [==============================] - 1s 22us/sample - loss: 0.8256 - acc: 0.7530 - val_loss: 0.3048 - val_acc: 0.9147
# Training default initialization:
# Train on 54000 samples, validate on 6000 samples
# 54000/54000 [==============================] - 1s 26us/sample - loss: 0.6992 - acc: 0.7934 - val_loss: 0.2883 - val_acc: 0.9207
# Wrapping the env in a DummyVecEnv.
# WARNING:tensorflow:From /home/bingley/miniconda3/envs/metagen/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:191: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /home/bingley/miniconda3/envs/metagen/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /home/bingley/miniconda3/envs/metagen/lib/python3.6/site-packages/stable_baselines/common/policies.py:116: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /home/bingley/miniconda3/envs/metagen/lib/python3.6/site-packages/stable_baselines/common/input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/bingley/miniconda3/envs/metagen/lib/python3.6/site-packages/stable_baselines/common/policies.py:442: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f0528152b70>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f0528152b70>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f0528152b70>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f0528152b70>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:From /home/bingley/miniconda3/envs/metagen/lib/python3.6/site-packages/stable_baselines/common/tf_layers.py:123: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f04f0570b70>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f04f0570b70>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f04f0570b70>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f04f0570b70>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:From /home/bingley/miniconda3/envs/metagen/lib/python3.6/site-packages/stable_baselines/a2c/a2c.py:158: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /home/bingley/miniconda3/envs/metagen/lib/python3.6/site-packages/tensorflow/python/ops/clip_ops.py:286: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/bingley/miniconda3/envs/metagen/lib/python3.6/site-packages/stable_baselines/a2c/a2c.py:182: The name tf.train.RMSPropOptimizer is deprecated. Please use tf.compat.v1.train.RMSPropOptimizer instead.
#
# WARNING:tensorflow:From /home/bingley/miniconda3/envs/metagen/lib/python3.6/site-packages/tensorflow/python/training/rmsprop.py:119: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/bingley/miniconda3/envs/metagen/lib/python3.6/site-packages/stable_baselines/a2c/a2c.py:194: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# Training RL initialization:
# Train on 54000 samples, validate on 6000 samples
# 54000/54000 [==============================] - 2s 32us/sample - loss: 3.5607 - acc: 0.3745 - val_loss: 0.9436 - val_acc: 0.7020
# Reward:  -451.45446076206895
# Training RL initialization:
# Train on 54000 samples, validate on 6000 samples
# 54000/54000 [==============================] - 1s 23us/sample - loss: 1.6695 - acc: 0.5951 - val_loss: 0.6297 - val_acc: 0.8213
# Reward:  -46.53640439162675
# Training RL initialization:
# Train on 54000 samples, validate on 6000 samples
# 54000/54000 [==============================] - 3s 53us/sample - loss: 2.2478 - acc: 0.4595 - val_loss: 1.0534 - val_acc: 0.6498
# Reward:  -113.56603913442719
# Training RL initialization:
# Train on 54000 samples, validate on 6000 samples
# 54000/54000 [==============================] - 4s 70us/sample - loss: 2.3208 - acc: 0.5186 - val_loss: 0.7793 - val_acc: 0.7753
# Reward:  -124.99984888652588
# Training RL initialization:
# Train on 54000 samples, validate on 6000 samples
# 54000/54000 [==============================] - 4s 73us/sample - loss: 2.7044 - acc: 0.4265 - val_loss: 1.2979 - val_acc: 0.6435
# Reward:  -197.79629209742512
# ---------------------------------
# | explained_variance | 1.19e-07 |
# | fps                | 0        |
# | nupdates           | 1        |
# | policy_entropy     | 1.79e+03 |
# | total_timesteps    | 5        |
# | value_loss         | 5.48e+04 |
# ---------------------------------
# Training RL initialization:
# Train on 54000 samples, validate on 6000 samples
# 54000/54000 [==============================] - 4s 69us/sample - loss: 2.7266 - acc: 0.4478 - val_loss: 1.0912 - val_acc: 0.6533
# Reward:  -202.71394629954955
# Training RL initialization:
# Train on 54000 samples, validate on 6000 samples
# 54000/54000 [==============================] - 3s 63us/sample - loss: 2.6935 - acc: 0.5467 - val_loss: 0.7382 - val_acc: 0.7913
# Reward:  -195.4041226520012
# Training RL initialization:
# Train on 54000 samples, validate on 6000 samples
# 54000/54000 [==============================] - 4s 76us/sample - loss: 1.4627 - acc: 0.5490 - val_loss: 0.6392 - val_acc: 0.8220
# Reward:  -31.292309606244757
# Training RL initialization:
# Train on 54000 samples, validate on 6000 samples
# 54000/54000 [==============================] - 4s 78us/sample - loss: 2.2921 - acc: 0.5038 - val_loss: 1.0476 - val_acc: 0.7048
# Reward:  -120.41395645002716
# Training RL initialization:
# Train on 54000 samples, validate on 6000 samples
# 54000/54000 [==============================] - 4s 74us/sample - loss: 1.7045 - acc: 0.4894 - val_loss: 0.8662 - val_acc: 0.7418
# Reward:  -49.51724990396096
# Training RL initialization:
# Train on 54000 samples, validate on 6000 samples
# 54000/54000 [==============================] - 4s 80us/sample - loss: 2.5597 - acc: 0.4968 - val_loss: 0.9676 - val_acc: 0.7490
# Reward:  -167.7114747107079
# Training RL initialization:
# Train on 54000 samples, validate on 6000 samples
# 54000/54000 [==============================] - 4s 79us/sample - loss: 1.6130 - acc: 0.5341 - val_loss: 0.7466 - val_acc: 0.7782
# Reward:  -41.96852064910538
# Training RL initialization:
# Train on 54000 samples, validate on 6000 samples
# 54000/54000 [==============================] - 4s 79us/sample - loss: 4.0371 - acc: 0.2484 - val_loss: 1.9389 - val_acc: 0.3887
# Reward:  -657.9542512510112
# Training RL initialization:
# Train on 54000 samples, validate on 6000 samples
# 54000/54000 [==============================] - 4s 83us/sample - loss: 2.1336 - acc: 0.5674 - val_loss: 0.7116 - val_acc: 0.7852
# Reward:  -97.13261847940899
# Training RL initialization:
# Train on 54000 samples, validate on 6000 samples
# 54000/54000 [==============================] - 4s 78us/sample - loss: 1.2645 - acc: 0.6456 - val_loss: 0.5907 - val_acc: 0.8338
# Reward:  -20.219238320311828
# Training RL initialization:
# Train on 54000 samples, validate on 6000 samples
# 54000/54000 [==============================] - 4s 83us/sample - loss: 2.5543 - acc: 0.5182 - val_loss: 0.8001 - val_acc: 0.7770
# Reward:  -166.6448237233555
# Training RL initialization:
# Train on 54000 samples, validate on 6000 samples
# 54000/54000 [==============================] - 5s 84us/sample - loss: 2.7771 - acc: 0.5137 - val_loss: 0.9518 - val_acc: 0.6990
# Reward:  -214.17695549864055
# Training RL initialization:
# Train on 54000 samples, validate on 6000 samples
# 54000/54000 [==============================] - 4s 73us/sample - loss: 3.3099 - acc: 0.3684 - val_loss: 1.4255 - val_acc: 0.6355
# Reward:  -362.609779066844
# Training RL initialization:
# Train on 54000 samples, validate on 6000 samples
# 54000/54000 [==============================] -
# Training RL initialization:
# Train on 54000 samples, validate on 6000 samples
# 54000/54000 [==============================] - 7s 132us/sample - loss: 2.1898 - acc: 0.4319 - val_loss: 0.8670 - val_acc: 0.7198
# Reward:  -105.00443397695551
# Training RL initialization:
# Train on 54000 samples, validate on 6000 samples
# 54000/54000 [==============================] - 5s 86us/sample - loss: 1.5723 - acc: 0.5801 - val_loss: 0.5693 - val_acc: 0.8368
# Reward:  -38.868316346315346
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-eb83fae85adf> in <module>
#       1 from genetics import Ecosystem
#       2
# ----> 3 genes = Ecosystem(training_set, validation_set)
#
# ~/Projects/META-genetics/genetics.py in __init__(self, training_set, validation_set, num_epochs, max_iter, pop_size, num_generations, RL)
#      52             self.predictor_net = RLPredictorNet(self.predictor_env)
#      53
# ---> 54             self.predictor_net.train()
#      55         else:
#      56             self.predictor_net = SupervisedPredictorNet(training_set, validation_set)
#
# ~/Projects/META-genetics/predictor.py in train(self, total_timesteps)
#      28
#      29     def train(self, total_timesteps=2000):
# ---> 30         self.model.learn(total_timesteps)
#      31
#      32
#
# ~/miniconda3/envs/metagen/lib/python3.6/site-packages/stable_baselines/a2c/a2c.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps)
#     259                 callback.on_rollout_start()
#     260                 # true_reward is the reward without discount
# --> 261                 rollout = self.runner.run(callback)
#     262                 # unpack
#     263                 obs, states, rewards, masks, actions, values, ep_infos, true_reward = rollout
#
# ~/miniconda3/envs/metagen/lib/python3.6/site-packages/stable_baselines/common/runners.py in run(self, callback)
#      46         self.callback = callback
#      47         self.continue_training = True
# ---> 48         return self._run()
#      49
#      50     @abstractmethod
#
# ~/miniconda3/envs/metagen/lib/python3.6/site-packages/stable_baselines/a2c/a2c.py in _run(self)
#     358             if isinstance(self.env.action_space, gym.spaces.Box):
#     359                 clipped_actions = np.clip(actions, self.env.action_space.low, self.env.action_space.high)
# --> 360             obs, rewards, dones, infos = self.env.step(clipped_actions)
#     361
#     362             self.model.num_timesteps += self.n_envs
#
# ~/miniconda3/envs/metagen/lib/python3.6/site-packages/stable_baselines/common/vec_env/base_vec_env.py in step(self, actions)
#     148         """
#     149         self.step_async(actions)
# --> 150         return self.step_wait()
#     151
#     152     def get_images(self, *args, **kwargs) -> Sequence[np.ndarray]:
#
# ~/miniconda3/envs/metagen/lib/python3.6/site-packages/stable_baselines/common/vec_env/dummy_vec_env.py in step_wait(self)
#      40         for env_idx in range(self.num_envs):
#      41             obs, self.buf_rews[env_idx], self.buf_dones[env_idx], self.buf_infos[env_idx] =\
# ---> 42                 self.envs[env_idx].step(self.actions[env_idx])
#      43             if self.buf_dones[env_idx]:
#      44                 # save final observation where user can get it, then reset
#
# ~/Projects/META-genetics/GeneticEnvironment.py in step(self, pred_weights)
#      59
#      60         pred_individual = ClassifierNet(layer_dimensions=self.default_individual.layer_dimensions)
# ---> 61         pred_individual.load_from_lstm_prediction(pred_weights)
#      62
#      63         #print("Training default initialization:")
#
# ~/Projects/META-genetics/classifier_net.py in load_from_lstm_prediction(self, prediction)
#     161             layer_weights = lay.get_weights()
#     162             new_weights = self.load_layer(layer_weights, pred_lay, self.max_layer_size, self.max_layer_size)
# --> 163             lay.set_weights(new_weights)
#     164
#     165     def load_layer(self, actual_layer, pred_layer, input_shape, output_shape):
#
# ~/miniconda3/envs/metagen/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer.py in set_weights(self, weights)
#    1119                          'provided weight shape ' + str(w.shape))
#    1120       weight_value_tuples.append((p, w))
# -> 1121     backend.batch_set_value(weight_value_tuples)
#    1122
#    1123   def get_weights(self):
#
# ~/miniconda3/envs/metagen/lib/python3.6/site-packages/tensorflow/python/keras/backend.py in batch_set_value(tuples)
#    3069           assign_ops.append(assign_op)
#    3070           feed_dict[assign_placeholder] = value
# -> 3071         get_session().run(assign_ops, feed_dict=feed_dict)
#    3072
#    3073
#
# ~/miniconda3/envs/metagen/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     948     try:
#     949       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 950                          run_metadata_ptr)
#     951       if run_metadata:
#     952         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/miniconda3/envs/metagen/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1171     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1172       results = self._do_run(handle, final_targets, final_fetches,
# -> 1173                              feed_dict_tensor, options, run_metadata)
#    1174     else:
#    1175       results = []
#
# ~/miniconda3/envs/metagen/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1348     if handle is None:
#    1349       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1350                            run_metadata)
#    1351     else:
#    1352       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/miniconda3/envs/metagen/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1354   def _do_call(self, fn, *args):
#    1355     try:
# -> 1356       return fn(*args)
#    1357     except errors.OpError as e:
#    1358       message = compat.as_text(e.message)
#
# ~/miniconda3/envs/metagen/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1337     def _run_fn(feed_dict, fetch_list, target_list, options, run_metadata):
#    1338       # Ensure any changes to the graph are reflected in the runtime.
# -> 1339       self._extend_graph()
#    1340       return self._call_tf_sessionrun(
#    1341           options, feed_dict, fetch_list, target_list, run_metadata)
#
# ~/miniconda3/envs/metagen/lib/python3.6/site-packages/tensorflow/python/client/session.py in _extend_graph(self)
#    1372   def _extend_graph(self):
#    1373     with self._graph._session_run_lock():  # pylint: disable=protected-access
# -> 1374       tf_session.ExtendSession(self._session)
#    1375
#    1376   # The threshold to run garbage collection to delete dead tensors.
#
# KeyboardInterrupt:
